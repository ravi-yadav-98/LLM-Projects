# %%
import os
from langchain.chat_models import init_chat_model
from langchain.messages import HumanMessage, AIMessage, SystemMessage
from dotenv import load_dotenv 
load_dotenv()
# Out:
# True

# %%
model = init_chat_model("gpt-4o-mini")

# %%
response = model.invoke("Why do parrots have colorful feathers?")  #str, dict
print(response)
# Out:
# content='Parrots have colorful feathers for several reasons, primarily related to their survival and reproductive success:\n\n1. **Camouflage**: In their natural habitats, which often include dense forests and tropical regions, bright colors can help parrots blend in with their surroundings. This camouflage can protect them from predators.\n\n2. **Communication**: Colorful feathers play a significant role in social interactions among parrots. Bright plumage can be used for displays during courtship, helping attract mates. Males, in particular, often have more vivid colors to signal their health and genetic fitness to potential partners.\n\n3. **Species and Individual Identification**: The distinct coloration of different parrot species helps individuals identify one another. This is important in social species where recognizing kin or mates can enhance social bonding and cooperative behaviors.\n\n4. **Thermoregulation**: Though not a primary reason, variations in feather coloration can also reflect an adaptation to regulating body temperature by influencing heat absorption and reflectivity.\n\nOverall, the vibrant colors of parrot feathers are a result of evolutionary pressures that favor both survival and reproductive advantages in their environments.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 221, 'prompt_tokens': 15, 'total_tokens': 236, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_6c0d1490cb', 'id': 'chatcmpl-D6v7wUaitiMMXs6HrIMGMkVOMFqsT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c3c85-ea7f-7991-a8f3-89634c515b50-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 221, 'total_tokens': 236, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(response.content)
# Out:
# str

# %%
conversation = [
    SystemMessage("You are a helpful assistant that translates English to French."),
    HumanMessage("Translate: I love programming."),
    AIMessage("J'adore la programmation."),
    HumanMessage("Translate: I love building applications.")
]

response = model.invoke(conversation)
print(response)
# Out:
# content="J'adore créer des applications." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 6, 'prompt_tokens': 48, 'total_tokens': 54, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f4ae844694', 'id': 'chatcmpl-D6v8jN3Z2AH32AGTNU4wDwIzkuiFm', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c3c86-ab72-7822-928c-1cf309d93912-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 48, 'output_tokens': 6, 'total_tokens': 54, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="|", flush=True)
# Out:
# |Par|rots| have| colorful| feathers| for| several| reasons|,| primarily| related| to| their| survival|,| social| interactions|,| and| environmental| adaptations|.| Here| are| some| key| explanations|:
#
# |1|.| **|Cam|ouflage|**|:| In| their| natural| habitats|,| which| often| include| tropical| forests|,| vibrant| colors| can| help| parro|ts| blend| in| with| the| colorful| foliage| and| flowers|.| This| can| provide| protection| from| predators|.
#
# |2|.| **|Social| Sign|aling|**|:| Bright| plum|age| can| play| a| crucial| role| in| communication| and| social| interactions| among| parro|ts|.| Color|ful| feathers| can| indicate| health|,| vitality|,| and| genetic| fitness|,| helping| parro|ts| attract| mates|.| M|ales|,| in| particular|,| may| exhibit| more| vivid| colors| during| court|ship| displays| to| signal| their| suitability| as| mates|.
#
# |3|.| **|Species| and| Individual| Identification|**|:| Color|ful| feathers| help| parro|ts| distinguish| each| other| and| identify| different| species|,| which| is| crucial| in| their| social| structures| and| breeding| practices|.
#
# |4|.| **|Ther|more|g|ulation|**|:| In| some| cases|,| the| colors| may| help| in| therm|oreg|ulation|,| where| certain| pigments| can| reflect| or| absorb| light| in| a| way| that| helps| maintain| body| temperature| in| varying| environmental| conditions|.
#
# |5|.| **|Diet| and| Nutrition|**|:| The| pigments| that| contribute| to| feather| coloration| often| come| from| the| parro|ts|’| diet|,| which| includes| fruits|,| seeds|,| and| flowers| rich| in| carot|eno|ids|.| The| diet| influences| the| intensity| and| vibr|ancy| of| their| plum|age|,| further| indicating| overall| health| and| nutritional| status|.
#
# |Overall|,| the| bright| and| diverse| colors| of| par|rot| feathers| serve| multiple| functions| that| aid| in| their| survival| and| reproduction|.||||
